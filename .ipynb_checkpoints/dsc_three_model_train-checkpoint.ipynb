# %% [markdown]
# # Data Science Challenge Task Three
#
# This problem is a sequence transduction problem.

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# normalize per sample when you get the data initially

# %%
# loading data
import numpy as np

# features = np.load('drive/MyDrive/features.npy')
features = np.load('features.npy')
targets = np.load('target.npy')

print(f"features shape: {features.shape}\ntarget shape: {targets.shape}\n\n")
print(features[45])
print(targets[45])
# Out:
# features shape: (16117, 12, 500)
# target shape: (16117, 75)
#
#
# [[-0.00440467 -0.00387052 -0.0036176  ...  0.00226714  0.00193733
#    0.00164015]
#  [-0.00298815 -0.00273625 -0.00258574 ...  0.00506948  0.00472775
#    0.00441726]
#  [ 0.00141653  0.00113428  0.00103186 ...  0.00280234  0.00279042
#    0.00277711]
#  ...
#  [-0.00194262 -0.00163849 -0.00150573 ... -0.00281408 -0.00284701
#   -0.00287367]
#  [-0.00095135 -0.00088797 -0.00084339 ...  0.00217922  0.00206312
#    0.00195672]
#  [-0.00066972 -0.00066334 -0.00064254 ...  0.00291269  0.00279022
#    0.00267752]]
# [54. 49. 43. 35. 31. 27. 39. 36. 32. 28. 24. 21. 35. 27. 29. 33. 36. 39.
#  33. 28. 23. 43. 39. 36. 53. 50. 46. 13.  8. 19. 23. 31. 36. 27. 22. 18.
#  25. 20. 14. 20. 16. 39. 12. 34. 31.  9. 41. 48. 34. 14. 18. 58. 54. 52.
#  69. 65. 62. 47. 50. 62. 54.  9. 14. 20. 65. 68. 24. 31. 36. 19. 13.  9.
#  37. 34. 30.]

# %%
#normalizing data - min-max normalization accross 12 channels for X and across all samples for y

# normalize_X/y normalizes the feature/target array and returns it alongside min and max vals per channel

def normalize_X(X):
    min_vals = X.min(axis=(0,2), keepdims=True)
    # print(min_vals.shape)
    max_vals = X.max(axis=(0,2), keepdims=True)
    # print(max_vals.shape)
    range_vals = max_vals - min_vals
    max_vals[max_vals == 0] = 1
    norm_features = np.divide(X, max_vals)
    return norm_features
    # , min_vals, max_vals

def normalize_y(y):
    min_vals = y.min(axis=0)
    max_vals = y.max(axis=0)
    range_vals = max_vals - min_vals
    norm_targets = np.divide(y, max_vals)
    return norm_targets
    # , min_vals, max_vals

# denormalize X/y denormalizes the array back into its original state so I can plot it using the functions they gave
def denormalize_X(norm_X, mins, maxs):
    range_vals = maxs - mins
    og_features = (norm_X * range_vals) + mins
    return og_features

def denormalize_y(norm_y, mins, maxs):
    range_vals = maxs-mins
    og_targets = (norm_y * range_vals) + mins
    return og_targets

# %% [markdown]
# # Verify Normalization/Denormalization works by plotting examples for both X and y

# %%
from matplotlib import pyplot as plt
test_idx = 50
X_clean = features[test_idx].T
# X_norm = norm_X[test_idx].T

row = 3
column = 4
num_timesteps = 500
plt.figure(figsize=(10, 7))
titles = ["I", "II", "III", "aVR", "aVL", "aVF", "V1", "V2", "V3", "V4", "V5", "V6"]
reorder = {1:1,2:5,3:9,4:2,5:6,6:10,7:3,8:7,9:11,10:4,11:8,12:12} # reorder the leads to standard 12-lead ECG display


for i in range(X_clean.shape[1]):
    plt.subplot(row, column, reorder[i + 1])
    plt.plot(X_clean[0:num_timesteps,i],'r')
    plt.title(titles[i])
    plt.grid(visible=True, which='major', color='#666666', linestyle='-')
    plt.minorticks_on()
    plt.grid(visible=True, which='minor', color='#999999', linestyle='-', alpha=0.2)
    plt.xlabel('msec')
    plt.ylabel('mV')
plt.tight_layout()
plt.show()

# %%
    def train_test_split(X, y):
        # print(X[42])
        train_index = int(len(X) * .8)
        test_index = int(len(X) * .9)

        idxs = np.random.permutation(len(X))

        X = X[idxs]
        y = y[idxs]

        X_train = X[:train_index]
        y_train = y[:train_index]

        X_test = X[train_index:test_index]
        y_test = y[train_index:test_index]

        X_val = X[test_index:]
        y_val = y[test_index:]

        return X_train, y_train, X_test, y_test, X_val, y_val

# %%
X_train, y_train, X_test, y_test, X_val, y_val = train_test_split(features, targets)
# print(features.shape)

# %%
X_train_norm = normalize_X(X_train)
X_test_norm = normalize_X(X_test)
X_val_norm = normalize_X(X_val)

# y_train_norm = normalize_y(y_train)
# y_test_norm = normalize_y(y_test)
# y_val_norm = normalize_y(y_val)

# %%
print(f"training X shape{X_train_norm.shape}\ntesting X shape: {X_test_norm.shape}\nvalidating X shape{X_val_norm.shape}\n")
print(f"training y shape{y_train.shape}\ntesting y shape: {y_test.shape}\nvalidating y shape{y_val.shape}\n")

print(f"sum of X datasets equals number of samples: {X_train_norm.shape[0] + X_test_norm.shape[0] + X_val_norm.shape[0] == features.shape[0]}")
print(f"sum of y datasets equals number of samples: {y_train.shape[0] + y_test.shape[0] + y_val.shape[0] == targets.shape[0]}")
# Out:
# training X shape(12893, 12, 500)
# testing X shape: (1612, 12, 500)
# validating X shape(1612, 12, 500)
#
# training y shape(12893, 75)
# testing y shape: (1612, 75)
# validating y shape(1612, 75)
#
# sum of X datasets equals number of samples: True
# sum of y datasets equals number of samples: True

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# %%
class dataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
    def __len__(self):
        return len(self.features)
    def __getitem__(self, idx):
        feature = self.features[idx]
        label = self.labels[idx]
        feature = torch.tensor(feature, dtype=torch.float32)
        label = torch.tensor(label, dtype=torch.float32)
        return feature, label

batch_size = 32

train_set = dataset(X_train_norm, y_train)
test_set = dataset(X_test_norm, y_test)
val_set = dataset(X_val_norm, y_val)

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batch_size,shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=True)

train_iter = iter(train_loader)
input, label = next(train_iter)
print(f"input shape: {input.shape}\nlabel shape: {label.shape}")
# Out:
# input shape: torch.Size([32, 12, 500])
# label shape: torch.Size([32, 75])

# %%
#model class
class ECGNet(nn.Module):
    def __init__(self):
        super(ECGNet, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=12, out_channels=32, kernel_size=5, stride=1, padding=2)
        self.pool = nn.MaxPool1d(kernel_size=2,stride=2)
        self.batchnorm1 = nn.BatchNorm1d(32)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=5, stride=1, padding=2)
        self.batchnorm2 = nn.BatchNorm1d(64)
        self.pool2 = nn.MaxPool1d(kernel_size=2, stride=2)
        self.conv3 = nn.Conv1d(in_channels=64, out_channels=128,kernel_size=5,stride=1, padding=2)
        self.batchnorm3 = nn.BatchNorm1d(128)
        self.pool3 = nn.MaxPool1d(kernel_size=4,stride=4)
        self.conv4 = nn.Conv1d(in_channels=128, out_channels=256, kernel_size=5, stride=1, padding=2)
        self.batchnorm4 = nn.BatchNorm1d(256)
        self.drop = nn.Dropout(p=.4)
        self.fc1 = nn.Linear(7936, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 128)
        self.fc4 = nn.Linear(128,75)

    def forward(self, x):
        x = self.pool(self.batchnorm1(F.relu(self.conv1(x))))
        x = self.pool2(self.batchnorm2(F.relu(self.conv2(x))))
        x = F.relu(self.batchnorm3((self.conv3(x))))
        x = self.pool3(self.batchnorm4(F.relu(self.conv4(x))))
        x = x.view(x.size(0), -1)  # Flatten the tensor
        x = self.drop(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        return x


model = ECGNet()

# Dummy data for forward pass
dummy_input = torch.randn(32, 12, 500)
print(model.forward(dummy_input).shape)
# Out:
# torch.Size([32, 75])

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

summary(model,input=(12,500))
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ECGNet                                   --
# ├─Conv1d: 1-1                            1,952
# ├─MaxPool1d: 1-2                         --
# ├─BatchNorm1d: 1-3                       64
# ├─Conv1d: 1-4                            10,304
# ├─BatchNorm1d: 1-5                       128
# ├─MaxPool1d: 1-6                         --
# ├─Conv1d: 1-7                            41,088
# ├─BatchNorm1d: 1-8                       256
# ├─MaxPool1d: 1-9                         --
# ├─Conv1d: 1-10                           164,096
# ├─BatchNorm1d: 1-11                      512
# ├─Dropout: 1-12                          --
# ├─Linear: 1-13                           8,127,488
# ├─Linear: 1-14                           524,800
# ├─Linear: 1-15                           65,664
# ├─Linear: 1-16                           9,675
# =================================================================
# Total params: 8,946,027
# Trainable params: 8,946,027
# Non-trainable params: 0
# =================================================================

# %%
#training loop
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)


num_epochs = 100

# Check if CUDA is available and set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)  # Move model to the device (GPU or CPU)

val_loss_arr = []
train_loss_arr = []
# Training loop
for epoch in range(num_epochs):
    model.train()  # Set model to training mode
    running_loss = 0.0

    for i, (inputs, labels) in enumerate(train_loader):
        # Move data to the appropriate device (GPU or CPU)
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        # Accumulate the loss
        running_loss += loss.item()

        # Print batch-level loss
        if (i + 1) % 200 == 0:  # Print every 200 batches
            print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{i + 1}/{len(train_loader)}], Loss: {loss.item():.5f}")


    # Print epoch-level training loss
    epoch_loss = running_loss / len(train_loader)
    train_loss_arr.append(epoch_loss)
    print(f"Epoch [{epoch + 1}/{num_epochs}], Average Training Loss: {epoch_loss:.5f}")

    # Validation Phase
    model.eval()  # Set model to evaluation mode
    val_loss = 0.0

    with torch.no_grad():  # Disable gradient computation for validation
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to device
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()


    # Print epoch-level validation loss
    val_loss /= len(val_loader)
    val_loss_arr.append(val_loss)
    print(f"Epoch [{epoch + 1}/{num_epochs}], Validation Loss: {val_loss:.5f}")

print("Training complete.")
# torch.save(model.state_dict(), 'model2_state.pth')
# Out:
# Epoch [1/100], Batch [200/403], Loss: 416.23297
# Epoch [1/100], Batch [400/403], Loss: 298.00955
# Epoch [1/100], Average Training Loss: 535.03005
# Epoch [1/100], Validation Loss: 314.92265
# Epoch [2/100], Batch [200/403], Loss: 279.02271
# Epoch [2/100], Batch [400/403], Loss: 334.95901
# Epoch [2/100], Average Training Loss: 307.79583
# Epoch [2/100], Validation Loss: 297.82069
# Epoch [3/100], Batch [200/403], Loss: 301.19141
# Epoch [3/100], Batch [400/403], Loss: 247.44698
# Epoch [3/100], Average Training Loss: 289.15016
# Epoch [3/100], Validation Loss: 277.05772
# Epoch [4/100], Batch [200/403], Loss: 284.32571
# Epoch [4/100], Batch [400/403], Loss: 290.17554
# Epoch [4/100], Average Training Loss: 269.94088
# Epoch [4/100], Validation Loss: 255.30795
# Epoch [5/100], Batch [200/403], Loss: 228.11195
# Epoch [5/100], Batch [400/403], Loss: 271.43088
# Epoch [5/100], Average Training Loss: 251.21653
# Epoch [5/100], Validation Loss: 232.33085
# Epoch [6/100], Batch [200/403], Loss: 228.37335
# Epoch [6/100], Batch [400/403], Loss: 232.35977
# Epoch [6/100], Average Training Loss: 225.25565
# Epoch [6/100], Validation Loss: 211.22124
# Epoch [7/100], Batch [200/403], Loss: 144.80037
# Epoch [7/100], Batch [400/403], Loss: 213.67783
# Epoch [7/100], Average Training Loss: 201.45585
# Epoch [7/100], Validation Loss: 184.41983
# Epoch [8/100], Batch [200/403], Loss: 191.78778
# Epoch [8/100], Batch [400/403], Loss: 136.84752
# Epoch [8/100], Average Training Loss: 177.95916
# Epoch [8/100], Validation Loss: 159.51719
# Epoch [9/100], Batch [200/403], Loss: 173.42870
# Epoch [9/100], Batch [400/403], Loss: 120.08457
# Epoch [9/100], Average Training Loss: 160.60243
# Epoch [9/100], Validation Loss: 155.56779
# Epoch [10/100], Batch [200/403], Loss: 139.55460
# Epoch [10/100], Batch [400/403], Loss: 173.06943
# Epoch [10/100], Average Training Loss: 145.34387
# Epoch [10/100], Validation Loss: 138.80244
# Epoch [11/100], Batch [200/403], Loss: 122.20712
# Epoch [11/100], Batch [400/403], Loss: 118.28169
# Epoch [11/100], Average Training Loss: 132.99256
# Epoch [11/100], Validation Loss: 120.34769
# Epoch [12/100], Batch [200/403], Loss: 84.52666
# Epoch [12/100], Batch [400/403], Loss: 99.23561
# Epoch [12/100], Average Training Loss: 81.70210
# Epoch [12/100], Validation Loss: 71.91847
# Epoch [13/100], Batch [200/403], Loss: 53.53605
# Epoch [13/100], Batch [400/403], Loss: 62.35300
# Epoch [13/100], Average Training Loss: 67.95302
# Epoch [13/100], Validation Loss: 62.30708
# Epoch [14/100], Batch [200/403], Loss: 59.01624
# Epoch [14/100], Batch [400/403], Loss: 52.29520
# Epoch [14/100], Average Training Loss: 58.52352
# Epoch [14/100], Validation Loss: 52.54917
# Epoch [15/100], Batch [200/403], Loss: 51.95390
# Epoch [15/100], Batch [400/403], Loss: 58.94289
# Epoch [15/100], Average Training Loss: 52.73659
# Epoch [15/100], Validation Loss: 50.97561
# Epoch [16/100], Batch [200/403], Loss: 48.76242
# Epoch [16/100], Batch [400/403], Loss: 41.82996
# Epoch [16/100], Average Training Loss: 46.86725
# Epoch [16/100], Validation Loss: 43.36968
# Epoch [17/100], Batch [200/403], Loss: 40.82816
# Epoch [17/100], Batch [400/403], Loss: 41.99664
# Epoch [17/100], Average Training Loss: 42.60884
# Epoch [17/100], Validation Loss: 40.81243
# Epoch [18/100], Batch [200/403], Loss: 33.39678
# Epoch [18/100], Batch [400/403], Loss: 34.28006
# Epoch [18/100], Average Training Loss: 39.38168
# Epoch [18/100], Validation Loss: 34.95711
# Epoch [19/100], Batch [200/403], Loss: 45.64108
# Epoch [19/100], Batch [400/403], Loss: 37.85556
# Epoch [19/100], Average Training Loss: 38.65769
# Epoch [19/100], Validation Loss: 31.91810
# Epoch [20/100], Batch [200/403], Loss: 32.38044
# Epoch [20/100], Batch [400/403], Loss: 34.36689
# Epoch [20/100], Average Training Loss: 35.28121
# Epoch [20/100], Validation Loss: 29.86975
# Epoch [21/100], Batch [200/403], Loss: 38.72993
# Epoch [21/100], Batch [400/403], Loss: 32.66272
# Epoch [21/100], Average Training Loss: 31.19711
# Epoch [21/100], Validation Loss: 27.87246
# Epoch [22/100], Batch [200/403], Loss: 42.21789
# Epoch [22/100], Batch [400/403], Loss: 36.45557
# Epoch [22/100], Average Training Loss: 32.30955
# Epoch [22/100], Validation Loss: 26.53111
# Epoch [23/100], Batch [200/403], Loss: 28.68852
# Epoch [23/100], Batch [400/403], Loss: 23.05221
# Epoch [23/100], Average Training Loss: 31.83964
# Epoch [23/100], Validation Loss: 26.98570
# Epoch [24/100], Batch [200/403], Loss: 42.47204
# Epoch [24/100], Batch [400/403], Loss: 28.08407
# Epoch [24/100], Average Training Loss: 28.38729
# Epoch [24/100], Validation Loss: 22.40967
# Epoch [25/100], Batch [200/403], Loss: 27.84184
# Epoch [25/100], Batch [400/403], Loss: 30.46473
# Epoch [25/100], Average Training Loss: 27.89146
# Epoch [25/100], Validation Loss: 35.65921
# Epoch [26/100], Batch [200/403], Loss: 26.88666
# Epoch [26/100], Batch [400/403], Loss: 31.74436
# Epoch [26/100], Average Training Loss: 26.43721
# Epoch [26/100], Validation Loss: 24.82117
# Epoch [27/100], Batch [200/403], Loss: 27.12480
# Epoch [27/100], Batch [400/403], Loss: 20.83782
# Epoch [27/100], Average Training Loss: 26.44407
# Epoch [27/100], Validation Loss: 23.66442
# Epoch [28/100], Batch [200/403], Loss: 22.62183
# Epoch [28/100], Batch [400/403], Loss: 29.85209
# Epoch [28/100], Average Training Loss: 23.44627
# Epoch [28/100], Validation Loss: 25.41384
# Epoch [29/100], Batch [200/403], Loss: 18.23243
# Epoch [29/100], Batch [400/403], Loss: 25.12972
# Epoch [29/100], Average Training Loss: 23.35618
# Epoch [29/100], Validation Loss: 21.36441
# Epoch [30/100], Batch [200/403], Loss: 26.85078
# Epoch [30/100], Batch [400/403], Loss: 25.22673
# Epoch [30/100], Average Training Loss: 23.79227
# Epoch [30/100], Validation Loss: 30.80053
# Epoch [31/100], Batch [200/403], Loss: 22.09062
# Epoch [31/100], Batch [400/403], Loss: 21.60125
# Epoch [31/100], Average Training Loss: 24.36920
# Epoch [31/100], Validation Loss: 20.51253
# Epoch [32/100], Batch [200/403], Loss: 23.40867
# Epoch [32/100], Batch [400/403], Loss: 18.61832
# Epoch [32/100], Average Training Loss: 22.59048
# Epoch [32/100], Validation Loss: 18.69128
# Epoch [33/100], Batch [200/403], Loss: 22.06164
# Epoch [33/100], Batch [400/403], Loss: 23.83803
# Epoch [33/100], Average Training Loss: 20.75105
# Epoch [33/100], Validation Loss: 23.72335
# Epoch [34/100], Batch [200/403], Loss: 20.27508
# Epoch [34/100], Batch [400/403], Loss: 25.20323
# Epoch [34/100], Average Training Loss: 23.10551
# Epoch [34/100], Validation Loss: 24.95095
# Epoch [35/100], Batch [200/403], Loss: 21.15991
# Epoch [35/100], Batch [400/403], Loss: 25.83561
# Epoch [35/100], Average Training Loss: 20.74608
# Epoch [35/100], Validation Loss: 30.87339
# Epoch [36/100], Batch [200/403], Loss: 26.73097
# Epoch [36/100], Batch [400/403], Loss: 20.41578
# Epoch [36/100], Average Training Loss: 19.91794
# Epoch [36/100], Validation Loss: 21.98961
# Epoch [37/100], Batch [200/403], Loss: 15.98095
# Epoch [37/100], Batch [400/403], Loss: 17.94193
# Epoch [37/100], Average Training Loss: 18.84689
# Epoch [37/100], Validation Loss: 18.41018
# Epoch [38/100], Batch [200/403], Loss: 17.80058
# Epoch [38/100], Batch [400/403], Loss: 20.81744
# Epoch [38/100], Average Training Loss: 18.32493
# Epoch [38/100], Validation Loss: 17.16262
# Epoch [39/100], Batch [200/403], Loss: 20.32177
# Epoch [39/100], Batch [400/403], Loss: 19.74639
# Epoch [39/100], Average Training Loss: 17.99277
# Epoch [39/100], Validation Loss: 16.65500
# Epoch [40/100], Batch [200/403], Loss: 18.78925
# Epoch [40/100], Batch [400/403], Loss: 14.62580
# Epoch [40/100], Average Training Loss: 18.18136
# Epoch [40/100], Validation Loss: 16.39512
# Epoch [41/100], Batch [200/403], Loss: 18.03369
# Epoch [41/100], Batch [400/403], Loss: 20.03114
# Epoch [41/100], Average Training Loss: 18.48820
# Epoch [41/100], Validation Loss: 18.26200
# Epoch [42/100], Batch [200/403], Loss: 16.14898
# Epoch [42/100], Batch [400/403], Loss: 17.30685
# Epoch [42/100], Average Training Loss: 17.74137
# Epoch [42/100], Validation Loss: 16.01293
# Epoch [43/100], Batch [200/403], Loss: 23.78561
# Epoch [43/100], Batch [400/403], Loss: 19.47414
# Epoch [43/100], Average Training Loss: 17.97976
# Epoch [43/100], Validation Loss: 20.80883
# Epoch [44/100], Batch [200/403], Loss: 15.92743
# Epoch [44/100], Batch [400/403], Loss: 17.70839
# Epoch [44/100], Average Training Loss: 17.80699
# Epoch [44/100], Validation Loss: 16.95894
# Epoch [45/100], Batch [200/403], Loss: 19.06961
# Epoch [45/100], Batch [400/403], Loss: 15.66389
# Epoch [45/100], Average Training Loss: 18.30413
# Epoch [45/100], Validation Loss: 16.81272
# Epoch [46/100], Batch [200/403], Loss: 16.30904
# Epoch [46/100], Batch [400/403], Loss: 18.55285
# Epoch [46/100], Average Training Loss: 16.33860
# Epoch [46/100], Validation Loss: 15.12092
# Epoch [47/100], Batch [200/403], Loss: 11.81381
# Epoch [47/100], Batch [400/403], Loss: 16.42968
# Epoch [47/100], Average Training Loss: 15.67622
# Epoch [47/100], Validation Loss: 18.69079
# Epoch [48/100], Batch [200/403], Loss: 25.45878
# Epoch [48/100], Batch [400/403], Loss: 14.13364
# Epoch [48/100], Average Training Loss: 16.81599
# Epoch [48/100], Validation Loss: 15.04292
# Epoch [49/100], Batch [200/403], Loss: 15.27798
# Epoch [49/100], Batch [400/403], Loss: 13.68314
# Epoch [49/100], Average Training Loss: 15.46845
# Epoch [49/100], Validation Loss: 16.08769
# Epoch [50/100], Batch [200/403], Loss: 13.43336
# Epoch [50/100], Batch [400/403], Loss: 20.07404
# Epoch [50/100], Average Training Loss: 15.59657
# Epoch [50/100], Validation Loss: 15.86033
# Epoch [51/100], Batch [200/403], Loss: 14.99767
# Epoch [51/100], Batch [400/403], Loss: 16.75774
# Epoch [51/100], Average Training Loss: 15.94053
# Epoch [51/100], Validation Loss: 15.80309
# Epoch [52/100], Batch [200/403], Loss: 19.04352
# Epoch [52/100], Batch [400/403], Loss: 13.19777
# Epoch [52/100], Average Training Loss: 15.26719
# Epoch [52/100], Validation Loss: 14.19600
# Epoch [53/100], Batch [200/403], Loss: 14.10331
# Epoch [53/100], Batch [400/403], Loss: 13.60555
# Epoch [53/100], Average Training Loss: 14.25774
# Epoch [53/100], Validation Loss: 13.63371
# Epoch [54/100], Batch [200/403], Loss: 13.58959
# Epoch [54/100], Batch [400/403], Loss: 14.18001
# Epoch [54/100], Average Training Loss: 14.34411
# Epoch [54/100], Validation Loss: 13.88024
# Epoch [55/100], Batch [200/403], Loss: 13.72808
# Epoch [55/100], Batch [400/403], Loss: 13.67005
# Epoch [55/100], Average Training Loss: 14.67845
# Epoch [55/100], Validation Loss: 14.16450
# Epoch [56/100], Batch [200/403], Loss: 13.90781
# Epoch [56/100], Batch [400/403], Loss: 12.91130
# Epoch [56/100], Average Training Loss: 14.25574
# Epoch [56/100], Validation Loss: 14.58958
# Epoch [57/100], Batch [200/403], Loss: 19.06524
# Epoch [57/100], Batch [400/403], Loss: 17.48683
# Epoch [57/100], Average Training Loss: 17.17425
# Epoch [57/100], Validation Loss: 18.13648
# Epoch [58/100], Batch [200/403], Loss: 14.97553
# Epoch [58/100], Batch [400/403], Loss: 12.51300
# Epoch [58/100], Average Training Loss: 15.59693
# Epoch [58/100], Validation Loss: 13.01714
# Epoch [59/100], Batch [200/403], Loss: 11.79760
# Epoch [59/100], Batch [400/403], Loss: 14.32833
# Epoch [59/100], Average Training Loss: 12.90752
# Epoch [59/100], Validation Loss: 13.91916
# Epoch [60/100], Batch [200/403], Loss: 15.76578
# Epoch [60/100], Batch [400/403], Loss: 13.06797
# Epoch [60/100], Average Training Loss: 13.37360
# Epoch [60/100], Validation Loss: 13.19007
# Epoch [61/100], Batch [200/403], Loss: 13.94148
# Epoch [61/100], Batch [400/403], Loss: 17.03296
# Epoch [61/100], Average Training Loss: 13.45602
# Epoch [61/100], Validation Loss: 13.31635
# Epoch [62/100], Batch [200/403], Loss: 16.04859
# Epoch [62/100], Batch [400/403], Loss: 12.60675
# Epoch [62/100], Average Training Loss: 13.07863
# Epoch [62/100], Validation Loss: 13.94632
# Epoch [63/100], Batch [200/403], Loss: 11.12134
# Epoch [63/100], Batch [400/403], Loss: 10.94880
# Epoch [63/100], Average Training Loss: 13.03347
# Epoch [63/100], Validation Loss: 11.81790
# Epoch [64/100], Batch [200/403], Loss: 12.29090
# Epoch [64/100], Batch [400/403], Loss: 15.48225
# Epoch [64/100], Average Training Loss: 13.73146
# Epoch [64/100], Validation Loss: 14.30088
# Epoch [65/100], Batch [200/403], Loss: 12.61803
# Epoch [65/100], Batch [400/403], Loss: 15.57306
# Epoch [65/100], Average Training Loss: 13.17646
# Epoch [65/100], Validation Loss: 11.98917
# Epoch [66/100], Batch [200/403], Loss: 13.76981
# Epoch [66/100], Batch [400/403], Loss: 12.93651
# Epoch [66/100], Average Training Loss: 12.96632
# Epoch [66/100], Validation Loss: 12.44462
# Epoch [67/100], Batch [200/403], Loss: 13.55356
# Epoch [67/100], Batch [400/403], Loss: 16.10624
# Epoch [67/100], Average Training Loss: 13.56580
# Epoch [67/100], Validation Loss: 20.62034
# Epoch [68/100], Batch [200/403], Loss: 10.51035
# Epoch [68/100], Batch [400/403], Loss: 21.63173
# Epoch [68/100], Average Training Loss: 14.26972
# Epoch [68/100], Validation Loss: 14.51355
# Epoch [69/100], Batch [200/403], Loss: 12.06931
# Epoch [69/100], Batch [400/403], Loss: 18.87180
# Epoch [69/100], Average Training Loss: 13.84920
# Epoch [69/100], Validation Loss: 12.72349
# Epoch [70/100], Batch [200/403], Loss: 10.50237
# Epoch [70/100], Batch [400/403], Loss: 10.63647
# Epoch [70/100], Average Training Loss: 12.63762
# Epoch [70/100], Validation Loss: 12.16198
# Epoch [71/100], Batch [200/403], Loss: 12.05544
# Epoch [71/100], Batch [400/403], Loss: 12.72239
# Epoch [71/100], Average Training Loss: 11.75352
# Epoch [71/100], Validation Loss: 11.25771
# Epoch [72/100], Batch [200/403], Loss: 9.55981
# Epoch [72/100], Batch [400/403], Loss: 10.59693
# Epoch [72/100], Average Training Loss: 12.10232
# Epoch [72/100], Validation Loss: 11.99807
# Epoch [73/100], Batch [200/403], Loss: 9.14923
# Epoch [73/100], Batch [400/403], Loss: 11.84828
# Epoch [73/100], Average Training Loss: 11.59046
# Epoch [73/100], Validation Loss: 12.04865
# Epoch [74/100], Batch [200/403], Loss: 9.31759
# Epoch [74/100], Batch [400/403], Loss: 10.24369
# Epoch [74/100], Average Training Loss: 11.88160
# Epoch [74/100], Validation Loss: 12.18124
# Epoch [75/100], Batch [200/403], Loss: 10.52612
# Epoch [75/100], Batch [400/403], Loss: 14.18432
# Epoch [75/100], Average Training Loss: 12.20500
# Epoch [75/100], Validation Loss: 11.04137
# Epoch [76/100], Batch [200/403], Loss: 8.80186
# Epoch [76/100], Batch [400/403], Loss: 14.33848
# Epoch [76/100], Average Training Loss: 11.86895
# Epoch [76/100], Validation Loss: 12.61857
# Epoch [77/100], Batch [200/403], Loss: 12.66978
# Epoch [77/100], Batch [400/403], Loss: 11.04583
# Epoch [77/100], Average Training Loss: 12.98632
# Epoch [77/100], Validation Loss: 12.13006
# Epoch [78/100], Batch [200/403], Loss: 10.48303
# Epoch [78/100], Batch [400/403], Loss: 14.97905
# Epoch [78/100], Average Training Loss: 11.76754
# Epoch [78/100], Validation Loss: 11.37748
# Epoch [79/100], Batch [200/403], Loss: 11.18362
# Epoch [79/100], Batch [400/403], Loss: 10.35919
# Epoch [79/100], Average Training Loss: 11.39167
# Epoch [79/100], Validation Loss: 11.50223
# Epoch [80/100], Batch [200/403], Loss: 11.51825
# Epoch [80/100], Batch [400/403], Loss: 8.94818
# Epoch [80/100], Average Training Loss: 11.11014
# Epoch [80/100], Validation Loss: 12.17120
# Epoch [81/100], Batch [200/403], Loss: 8.24327
# Epoch [81/100], Batch [400/403], Loss: 10.41842
# Epoch [81/100], Average Training Loss: 11.40695
# Epoch [81/100], Validation Loss: 11.62401
# Epoch [82/100], Batch [200/403], Loss: 12.11747
# Epoch [82/100], Batch [400/403], Loss: 15.54624
# Epoch [82/100], Average Training Loss: 14.17294
# Epoch [82/100], Validation Loss: 12.71607
# Epoch [83/100], Batch [200/403], Loss: 9.37187
# Epoch [83/100], Batch [400/403], Loss: 12.10226
# Epoch [83/100], Average Training Loss: 10.72894
# Epoch [83/100], Validation Loss: 10.13243
# Epoch [84/100], Batch [200/403], Loss: 10.94634
# Epoch [84/100], Batch [400/403], Loss: 14.47206
# Epoch [84/100], Average Training Loss: 10.67963
# Epoch [84/100], Validation Loss: 11.10224
# Epoch [85/100], Batch [200/403], Loss: 12.98323
# Epoch [85/100], Batch [400/403], Loss: 9.63521
# Epoch [85/100], Average Training Loss: 11.21816
# Epoch [85/100], Validation Loss: 10.61933
# Epoch [86/100], Batch [200/403], Loss: 9.88034
# Epoch [86/100], Batch [400/403], Loss: 11.98823
# Epoch [86/100], Average Training Loss: 10.69955
# Epoch [86/100], Validation Loss: 10.71659
# Epoch [87/100], Batch [200/403], Loss: 12.19480
# Epoch [87/100], Batch [400/403], Loss: 9.54885
# Epoch [87/100], Average Training Loss: 10.65302
# Epoch [87/100], Validation Loss: 10.56656
# Epoch [88/100], Batch [200/403], Loss: 11.43999
# Epoch [88/100], Batch [400/403], Loss: 10.60349
# Epoch [88/100], Average Training Loss: 10.35670
# Epoch [88/100], Validation Loss: 9.79265
# Epoch [89/100], Batch [200/403], Loss: 10.58781
# Epoch [89/100], Batch [400/403], Loss: 11.31082
# Epoch [89/100], Average Training Loss: 10.62716
# Epoch [89/100], Validation Loss: 10.45628
# Epoch [90/100], Batch [200/403], Loss: 10.68283
# Epoch [90/100], Batch [400/403], Loss: 9.86158
# Epoch [90/100], Average Training Loss: 10.46699
# Epoch [90/100], Validation Loss: 10.41095
# Epoch [91/100], Batch [200/403], Loss: 12.96619
# Epoch [91/100], Batch [400/403], Loss: 19.89067
# Epoch [91/100], Average Training Loss: 11.76802
# Epoch [91/100], Validation Loss: 19.52471
# Epoch [92/100], Batch [200/403], Loss: 8.71125
# Epoch [92/100], Batch [400/403], Loss: 11.87297
# Epoch [92/100], Average Training Loss: 10.99094
# Epoch [92/100], Validation Loss: 11.78674
# Epoch [93/100], Batch [200/403], Loss: 11.39067
# Epoch [93/100], Batch [400/403], Loss: 8.11062
# Epoch [93/100], Average Training Loss: 10.12510
# Epoch [93/100], Validation Loss: 9.98600
# Epoch [94/100], Batch [200/403], Loss: 9.67985
# Epoch [94/100], Batch [400/403], Loss: 10.02305
# Epoch [94/100], Average Training Loss: 9.81030
# Epoch [94/100], Validation Loss: 9.74925
# Epoch [95/100], Batch [200/403], Loss: 10.53527
# Epoch [95/100], Batch [400/403], Loss: 9.50840
# Epoch [95/100], Average Training Loss: 9.96025
# Epoch [95/100], Validation Loss: 10.11568
# Epoch [96/100], Batch [200/403], Loss: 13.81713
# Epoch [96/100], Batch [400/403], Loss: 11.98246
# Epoch [96/100], Average Training Loss: 11.42684
# Epoch [96/100], Validation Loss: 10.60328
# Epoch [97/100], Batch [200/403], Loss: 10.05943
# Epoch [97/100], Batch [400/403], Loss: 9.69296
# Epoch [97/100], Average Training Loss: 9.94896
# Epoch [97/100], Validation Loss: 9.53449
# Epoch [98/100], Batch [200/403], Loss: 8.82125
# Epoch [98/100], Batch [400/403], Loss: 11.93877
# Epoch [98/100], Average Training Loss: 9.72548
# Epoch [98/100], Validation Loss: 10.14502
# Epoch [99/100], Batch [200/403], Loss: 10.64106
# Epoch [99/100], Batch [400/403], Loss: 9.75663
# Epoch [99/100], Average Training Loss: 9.76937
# Epoch [99/100], Validation Loss: 9.56401
# Epoch [100/100], Batch [200/403], Loss: 9.59493
# Epoch [100/100], Batch [400/403], Loss: 9.96135
# Epoch [100/100], Average Training Loss: 9.64680
# Epoch [100/100], Validation Loss: 10.09713
# Training complete.

# %%
model.eval()  # Set model to evaluation mode
test_loss = 0.0
total_batches = len(test_loader)

pred = []
true = []

mae = nn.L1Loss(reduction='mean')
mae_test_loss = 0
with torch.no_grad():  # Disable gradient computation for testing
    for i, (inputs, labels) in enumerate(test_loader):
        # Move data to the appropriate device (GPU or CPU)
        inputs, labels = inputs.to(device), labels.to(device)

        # Forward pass
        outputs = model(inputs)
        # pred.append(outputs)
        loss = criterion(outputs, labels)
        # true.append(labels)
        maes = mae(outputs, labels)
        # Accumulate the test loss
        test_loss += loss.item()
        mae_test_loss += maes.item()
        # Print batch-level details
        print(f"Batch [{i + 1}/{total_batches}], Loss: {loss.item():.4f}, MAE: {maes.item():.4f}")

# Calculate the average test loss
average_test_loss = test_loss / total_batches
average_mae_loss = mae_test_loss / total_batches

print(f"Average Test Loss: {average_test_loss:.4f}\nAverage MAE Loss: {average_mae_loss:.4f}")
# pred = model(X_test)
# true = y_test
# Out:
# Batch [1/51], Loss: 9.3234, MAE: 2.2476
# Batch [2/51], Loss: 8.7380, MAE: 2.2634
# Batch [3/51], Loss: 7.2805, MAE: 2.0275
# Batch [4/51], Loss: 8.3314, MAE: 2.1623
# Batch [5/51], Loss: 9.5998, MAE: 2.2750
# Batch [6/51], Loss: 10.3873, MAE: 2.3141
# Batch [7/51], Loss: 10.5633, MAE: 2.4020
# Batch [8/51], Loss: 10.3593, MAE: 2.4536
# Batch [9/51], Loss: 11.6334, MAE: 2.6064
# Batch [10/51], Loss: 10.9866, MAE: 2.4365
# Batch [11/51], Loss: 9.5263, MAE: 2.2852
# Batch [12/51], Loss: 13.1029, MAE: 2.5203
# Batch [13/51], Loss: 10.4905, MAE: 2.4391
# Batch [14/51], Loss: 8.2108, MAE: 2.1916
# Batch [15/51], Loss: 10.1627, MAE: 2.3713
# Batch [16/51], Loss: 8.3495, MAE: 2.1994
# Batch [17/51], Loss: 10.0943, MAE: 2.3893
# Batch [18/51], Loss: 9.5503, MAE: 2.2967
# Batch [19/51], Loss: 8.5050, MAE: 2.1882
# Batch [20/51], Loss: 8.8991, MAE: 2.1894
# Batch [21/51], Loss: 8.9210, MAE: 2.2967
# Batch [22/51], Loss: 10.7310, MAE: 2.4699
# Batch [23/51], Loss: 12.0399, MAE: 2.6467
# Batch [24/51], Loss: 7.7540, MAE: 2.0723
# Batch [25/51], Loss: 10.2752, MAE: 2.3765
# Batch [26/51], Loss: 8.7812, MAE: 2.2029
# Batch [27/51], Loss: 9.0772, MAE: 2.2913
# Batch [28/51], Loss: 10.5217, MAE: 2.4024
# Batch [29/51], Loss: 14.6872, MAE: 2.6793
# Batch [30/51], Loss: 11.5744, MAE: 2.5096
# Batch [31/51], Loss: 11.1948, MAE: 2.4984
# Batch [32/51], Loss: 9.0634, MAE: 2.2592
# Batch [33/51], Loss: 18.6584, MAE: 2.6137
# Batch [34/51], Loss: 10.3421, MAE: 2.3739
# Batch [35/51], Loss: 7.7825, MAE: 2.1419
# Batch [36/51], Loss: 9.9586, MAE: 2.3500
# Batch [37/51], Loss: 9.9532, MAE: 2.3705
# Batch [38/51], Loss: 9.9469, MAE: 2.3379
# Batch [39/51], Loss: 10.7600, MAE: 2.4523
# Batch [40/51], Loss: 12.7858, MAE: 2.6907
# Batch [41/51], Loss: 13.7172, MAE: 2.5075
# Batch [42/51], Loss: 8.8658, MAE: 2.2414
# Batch [43/51], Loss: 9.0041, MAE: 2.2201
# Batch [44/51], Loss: 10.6305, MAE: 2.4361
# Batch [45/51], Loss: 13.3133, MAE: 2.4331
# Batch [46/51], Loss: 10.1434, MAE: 2.3711
# Batch [47/51], Loss: 9.7283, MAE: 2.3483
# Batch [48/51], Loss: 14.0782, MAE: 2.8416
# Batch [49/51], Loss: 14.6096, MAE: 2.8679
# Batch [50/51], Loss: 8.3540, MAE: 2.1620
# Batch [51/51], Loss: 8.8769, MAE: 2.2557
# Average Test Loss: 10.3966
# Average MAE Loss: 2.3722

# %%
plt.figure(figsize = (10,6))
plt.plot(val_loss_arr)
plt.plot(range(len(train_loss_arr)), train_loss_arr, label='Training Loss', color='green')

# Plot validation loss
plt.plot(range(len(val_loss_arr)), val_loss_arr, label='Validation Loss',color='blue')

plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.title('Training/Validation loss per epoch')
plt.legend()
plt.savefig('train_v_loss_task3.png')
# plt.imshow(cmap='viridis')
plt.show()

# print(len(val_loss_arr))
from matplotlib import colormaps
# list(colormaps)

# %%
#saving model

# saved_model = ECGNet()
# PATH = 'models/model_state_dict.pt'
# PATH = 'models/model.pt'

# torch.save(model, PATH)

# %%
# using model to predict and plotting those predictions

test_iter = iter(test_loader)
testx, testy = next(test_iter)
predy = model(testx[4].reshape(1,12,500))
testy = testy[4].reshape(1,75)

# %%
import __main__
PATH = "./models/model.pt"
model = torch.load(PATH)
setattr(__main__, "ECGNet",model)

# testyy = model2(testx[0].reshape(1,12,500))
# Out:
# /var/folders/b8/l3nyhzgx34v0tz4w1c09sc280000gn/T/ipykernel_2791/694587656.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(PATH)
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[25], line 3
#       1 import __main__
#       2 PATH = "./models/model.pt"
# ----> 3 model = torch.load(PATH)
#       4 setattr(__main__, "ECGNet",model)
#       6 # testyy = model2(testx[0].reshape(1,12,500))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/serialization.py:1097, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1095             except RuntimeError as e:
#    1096                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1097         return _load(
#    1098             opened_zipfile,
#    1099             map_location,
#    1100             pickle_module,
#    1101             overall_storage=overall_storage,
#    1102             **pickle_load_args,
#    1103         )
#    1104 if mmap:
#    1105     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/serialization.py:1525, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1522 # Needed for tensors where storage device and rebuild tensor device are
#    1523 # not connected (wrapper subclasses and tensors rebuilt using numpy)
#    1524 torch._utils._thread_local_state.map_location = map_location
# -> 1525 result = unpickler.load()
#    1526 del torch._utils._thread_local_state.map_location
#    1528 torch._utils._validate_loaded_sparse_tensors()
#
# UnpicklingError: NEWOBJ class argument must be a type, not ECGNet

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(10,5))
ax1.imshow(testy.T, cmap='jet', interpolation='nearest', aspect='auto')
ax1.set_title("Actual")
ax2.imshow(predy.T.detach().numpy(), cmap='jet', interpolation='nearest', aspect='auto')
ax2.set_title("Predicted")
# ax1.xticks([])
# ax2.xticks([])
plt.setp(plt.gcf().get_axes(), xticks=[])
plt.savefig("plots/actual_v_pred_t3")
plt.show()
